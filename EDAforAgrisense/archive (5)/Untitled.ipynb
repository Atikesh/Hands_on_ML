# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Crop_recommendation.csv')

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.corr()
# Out:
# C:\Users\Windows 11\AppData\Local\Temp\ipykernel_17732\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P           -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K           -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph           0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# N            0.059020
# P           -0.063839
# ...

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
sns.barplot(x='N',y='label',data=df)
# Out:
# <Axes: xlabel='N', ylabel='label'>

# %%
sns.barplot(x='P',y='label',data=df)
# Out:
# <Axes: xlabel='P', ylabel='label'>

# %%
sns.barplot(x='K',y='label',data=df)
# Out:
# <Axes: xlabel='K', ylabel='label'>

# %%
sns.heatmap(pd.crosstab(df['N'],df['label']))
# Out:
# <Axes: xlabel='label', ylabel='N'>

# %%
sns.heatmap(pd.crosstab(df['P'],df['label']))
# Out:
# <Axes: xlabel='label', ylabel='P'>

# %%
sns.heatmap(pd.crosstab(df['K'],df['label']))
# Out:
# <Axes: xlabel='label', ylabel='K'>

# %%
sns.scatterplot(df['N'],df['P'],hue=df['K'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 sns.scatterplot(df['N'],df['P'],hue=df['K'])
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
sns.scatterplot(data=df, x='N', y='label')
# Out:
# <Axes: xlabel='N', ylabel='label'>

# %%
sns.scatterplot(data=df, x='K', y='label')
# Out:
# <Axes: xlabel='K', ylabel='label'>

# %%
sns.scatterplot(data=df, x='P', y='label')
# Out:
# <Axes: xlabel='P', ylabel='label'>

# %%
sns.barplot(x='rainfall',y='label',data=df)
# Out:
# <Axes: xlabel='rainfall', ylabel='label'>

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
sns.barplot(x='temperature',y='label',data=df)
# Out:
# <Axes: xlabel='temperature', ylabel='label'>

# %%
sns.barplot(x='humidity',y='label',data=df)
# Out:
# <Axes: xlabel='humidity', ylabel='label'>

# %%
sns.barplot(x='ph',y='label',data=df)
# Out:
# <Axes: xlabel='ph', ylabel='label'>

# %%
sns.scatterplot(data=df, x='K', y='ph',hue='label')
# Out:
# <Axes: xlabel='K', ylabel='ph'>

# %%
sns.scatterplot(data=df, x='P', y='ph',hue='label')
# Out:
# <Axes: xlabel='P', ylabel='ph'>

# %%
sns.scatterplot(data=df, x='N', y='ph',hue='label')
# Out:
# <Axes: xlabel='N', ylabel='ph'>

# %%
df.cov()
# Out:
# C:\Users\Windows 11\AppData\Local\Temp\ipykernel_17732\1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                        N            P            K  temperature    humidity  \
# N            1362.889537  -281.860096  -262.727147     4.954622  156.730700
# P            -281.860096  1088.068460  1229.998647   -21.303478  -87.197323
# K            -262.727147  1229.998647  2565.212869   -41.134229  215.215502
# temperature     4.954622   -21.303478   -41.134229    25.641550   23.147400
# humidity      156.730700   -87.197323   215.215502    23.147400  495.677307
# ph              2.762395    -3.523487    -6.644240    -0.069739   -0.146161
# rainfall      119.747146  -115.730685  -148.811212    -8.372180  115.534462
#
#                    ph     rainfall
# ...
